# %% [markdown]
# <a href="https://colab.research.google.com/github/EduardaSantosDiniz/Praticando_Python/blob/main/PraticandoPythoni.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Aprendendo Básico Pandas**

# %%
import pandas as pd

df = pd.read_excel('/content/base_vendas_supermercado.xlsx')
df
# Out:
#      ID_Venda Filial          Cidade     Genero Produto  Preco_Unitario  \
# 0           1      C  Belo Horizonte   Feminino   Carne           73.63
# 1           2      A       São Paulo  Masculino   Arroz           93.96
# 2           3      C       São Paulo  Masculino     Pão           19.76
# 3           4      C       São Paulo   Feminino   Arroz            8.52
# 4           5      A       São Paulo  Masculino  Açúcar           74.63
# ..        ...    ...             ...        ...     ...             ...
# 295       296      B       São Paulo  Masculino   Carne           71.15
# 296       297      B  Belo Horizonte  Masculino   Carne           92.67
# 297       298      B       São Paulo  Masculino  Feijão           19.70
# 298       299      B  Belo Horizonte  Masculino     Pão           57.66
# 299       300      B       São Paulo   Feminino   Leite           91.72
#
#      Quantidade Forma_Pagamento       Data   Hora  Avaliacao
# ...

# %%
#criando a coluna com o faturamento
df["Faturamento"] = df['Preco_Unitario'] * df['Quantidade']
df
# Out:
#      ID_Venda Filial          Cidade     Genero Produto  Preco_Unitario  \
# 0           1      C  Belo Horizonte   Feminino   Carne           73.63
# 1           2      A       São Paulo  Masculino   Arroz           93.96
# 2           3      C       São Paulo  Masculino     Pão           19.76
# 3           4      C       São Paulo   Feminino   Arroz            8.52
# 4           5      A       São Paulo  Masculino  Açúcar           74.63
# ..        ...    ...             ...        ...     ...             ...
# 295       296      B       São Paulo  Masculino   Carne           71.15
# 296       297      B  Belo Horizonte  Masculino   Carne           92.67
# 297       298      B       São Paulo  Masculino  Feijão           19.70
# 298       299      B  Belo Horizonte  Masculino     Pão           57.66
# 299       300      B       São Paulo   Feminino   Leite           91.72
#
#      Quantidade Forma_Pagamento       Data   Hora  Avaliacao  Faturamento
# ...

# %%
#top 3 produtos com o faturamento mais alto
top = df.groupby(['Produto'])['Faturamento'].sum().sort_values(ascending=False)
top.head(3)
# Out:
# Produto
# Café     12559.89
# Carne    10360.30
# Pão      10043.83
# Name: Faturamento, dtype: float64

# %%
#criando a coluna com os dias da semana
df['DiaSemana'] = df['Data'].dt.day_name()
df
# Out:
#      ID_Venda Filial          Cidade     Genero Produto  Preco_Unitario  \
# 0           1      C  Belo Horizonte   Feminino   Carne           73.63
# 1           2      A       São Paulo  Masculino   Arroz           93.96
# 2           3      C       São Paulo  Masculino     Pão           19.76
# 3           4      C       São Paulo   Feminino   Arroz            8.52
# 4           5      A       São Paulo  Masculino  Açúcar           74.63
# ..        ...    ...             ...        ...     ...             ...
# 295       296      B       São Paulo  Masculino   Carne           71.15
# 296       297      B  Belo Horizonte  Masculino   Carne           92.67
# 297       298      B       São Paulo  Masculino  Feijão           19.70
# 298       299      B  Belo Horizonte  Masculino     Pão           57.66
# 299       300      B       São Paulo   Feminino   Leite           91.72
#
#      Quantidade Forma_Pagamento       Data   Hora  Avaliacao  Faturamento  \
# ...

# %%
#top 3 dias da semana com mais faturamento
dia_faturamento =df.groupby(['DiaSemana'])['Faturamento'].sum().sort_values(ascending=False)
dia_faturamento.head(3)
# Out:
# DiaSemana
# Thursday    14726.37
# Friday      11864.84
# Saturday    11276.81
# Name: Faturamento, dtype: float64

# %%
df['Hora'] = pd.to_datetime(df['Hora'], format="%H:%M").dt.hour.astype(int)

# Cria nova coluna "Periodo"
def definir_periodo(hora):
    if 5 <= hora < 12:
        return 'Manhã'
    elif 12 <= hora < 18:
        return 'Tarde'
    elif 18 <= hora < 24:
        return 'Noite'
    else:
        return 'Madrugada'

df['Periodo'] = df['Hora'].apply(definir_periodo)

df
# Out:
#      ID_Venda Filial          Cidade     Genero Produto  Preco_Unitario  \
# 0           1      C  Belo Horizonte   Feminino   Carne           73.63
# 1           2      A       São Paulo  Masculino   Arroz           93.96
# 2           3      C       São Paulo  Masculino     Pão           19.76
# 3           4      C       São Paulo   Feminino   Arroz            8.52
# 4           5      A       São Paulo  Masculino  Açúcar           74.63
# ..        ...    ...             ...        ...     ...             ...
# 295       296      B       São Paulo  Masculino   Carne           71.15
# 296       297      B  Belo Horizonte  Masculino   Carne           92.67
# 297       298      B       São Paulo  Masculino  Feijão           19.70
# 298       299      B  Belo Horizonte  Masculino     Pão           57.66
# 299       300      B       São Paulo   Feminino   Leite           91.72
#
#      Quantidade Forma_Pagamento       Data  Hora  Avaliacao  Faturamento  \
# ...

# %%
df.groupby(['Cidade'])['Faturamento'].sum().sort_values(ascending = False)
# Out:
# Cidade
# São Paulo         31735.40
# Belo Horizonte    21400.09
# Rio de Janeiro    21007.52
# Name: Faturamento, dtype: float64

# %%
faturamento_periodo = df.groupby(['Periodo'])['Faturamento'].sum().sort_values(ascending = False)
faturamento_periodo
# Out:
# Periodo
# Noite    30583.01
# Tarde    28466.34
# Manhã    15093.66
# Name: Faturamento, dtype: float64

# %%
df.groupby(['Filial'])['Faturamento'].sum().sort_values(ascending = False)
# Out:
# Filial
# C    26636.20
# A    24413.59
# B    23093.22
# Name: Faturamento, dtype: float64

# %%
df

def verifca_mes(Data):
  if Data.month == 1:
    return 'Janeiro'
  if Data.month == 2:
    return 'Fevereiro'
  if Data.month == 3:
    return 'Março'
  if Data.month == 4:
    return 'Abril'
  if Data.month == 5:
    return 'Maio'
  if Data.month == 6:
    return 'Junho'
  if Data.month == 7:
    return 'Julho'
  if Data.month == 8:
    return 'Agosto'
  if Data.month == 9:
    return 'Setembro'
  if Data.month == 10:
    return 'Outubro'
  if Data.month == 11:
    return 'Novembro'
  if Data.month == 12:
    return 'Dezembro'
df['Mes'] = df['Data'].apply(verifca_mes)
df
# Out:
#      ID_Venda Filial          Cidade     Genero Produto  Preco_Unitario  \
# 0           1      C  Belo Horizonte   Feminino   Carne           73.63
# 1           2      A       São Paulo  Masculino   Arroz           93.96
# 2           3      C       São Paulo  Masculino     Pão           19.76
# 3           4      C       São Paulo   Feminino   Arroz            8.52
# 4           5      A       São Paulo  Masculino  Açúcar           74.63
# ..        ...    ...             ...        ...     ...             ...
# 295       296      B       São Paulo  Masculino   Carne           71.15
# 296       297      B  Belo Horizonte  Masculino   Carne           92.67
# 297       298      B       São Paulo  Masculino  Feijão           19.70
# 298       299      B  Belo Horizonte  Masculino     Pão           57.66
# 299       300      B       São Paulo   Feminino   Leite           91.72
#
#      Quantidade Forma_Pagamento       Data  Hora  Avaliacao  Faturamento  \
# ...

# %%
filtro_mes = df.groupby(['Mes'])['Faturamento'].sum().sort_values(ascending = False)
filtro_mes
# Out:
# Mes
# Maio         8180.98
# Outubro      8039.55
# Junho        7717.87
# Março        7567.04
# Setembro     7065.74
# Fevereiro    6624.75
# Abril        6446.17
# Janeiro      5813.33
# Dezembro     5341.68
# Agosto       5013.74
# Novembro     4793.63
# Julho        1538.53
# Name: Faturamento, dtype: float64

# %%
df['Produto'].unique()
# Out:
# array(['Carne', 'Arroz', 'Pão', 'Açúcar', 'Café', 'Feijão', 'Macarrão',
#        'Leite'], dtype=object)

# %% [markdown]
# # **Aprendendo Seaborn**

# %% [markdown]
# **1. Gráfico de Dispersão (Scatterplot)**
#
# --otimo para encontrar padroes ou correlacoes

# %%
import seaborn as sns
sns.scatterplot(x= df['Faturamento'], y= df['Avaliacao'])
# Out:
# <Axes: xlabel='Faturamento', ylabel='Avaliacao'>

# %% [markdown]
# **2. Gráficos de Barras**

# %%
import seaborn as sns


sns.countplot(data=df, x="Produto", hue="Forma_Pagamento", order=df["Produto"].value_counts().index, hue_order=df["Forma_Pagamento"].unique(),  # Ordem do hue
    palette="pastel",                # Paleta de cores
    saturation=200,                  # Intensidade da cor
    dodge=True,                      # Separar barras por hue
    width=0.8,                       # Largura das barras
    orient="d",                      # Orientação vertical
    fill=True,                       # Barras preenchidas
    log_scale=False,                 # Sem escala logarítmica
    native_scale=False,             # Usa escala ordinal
    legend=True                      # Exibe legenda
)


#sns.countplot(data=df, x= "Produto", hue= "Forma_Pagamento")
# Out:
# <Axes: xlabel='Produto', ylabel='count'>

# %%
sns.countplot(data=df, x= "Produto", hue= "Forma_Pagamento")
# Out:
# <Axes: xlabel='Produto', ylabel='count'>

# %% [markdown]
# **3.Gráfico de Linha**
#
# --Usado para mostrar tendências ao longo do tempo ou sequências ordenadas.

# %%
sns.lineplot(x= df['DiaSemana'], y = df['Faturamento'])
# Out:
# <Axes: xlabel='DiaSemana', ylabel='Faturamento'>

# %% [markdown]
# **4. Histograma**
#
# --Exibe a distribuição de uma variável numérica.

# %%
sns.histplot(data=df, x='Produto', bins=20)
# Out:
# <Axes: xlabel='Produto', ylabel='Count'>

# %%
df['Produto'].value_counts().sort_values(ascending=False)
# Out:
# Produto
# Pão         45
# Arroz       39
# Café        39
# Feijão      38
# Macarrão    37
# Carne       35
# Leite       35
# Açúcar      32
# Name: count, dtype: int64

# %% [markdown]
# **5. Boxplot**
#
# --Mostra a distribuição, mediana, quartis e possíveis outliers.

# %%
sns.boxplot(x = df['Produto'], y = df['Faturamento'])
# Out:
# <Axes: xlabel='Produto', ylabel='Faturamento'>

# %% [markdown]
# **6. Violin Plot**
#
# --Combina o boxplot com a densidade da distribuição.

# %%
sns.violinplot(x = df['Produto'], y = df['Faturamento'])
# Out:
# <Axes: xlabel='Produto', ylabel='Faturamento'>

# %% [markdown]
# **7. Barplot**
#
# --Representa médias ou totais por categoria.

# %%
sns.barplot(x = df['Produto'], y = df['Faturamento'])
# Out:
# <Axes: xlabel='Produto', ylabel='Faturamento'>

# %% [markdown]
# **8. Jointplot**
#
# --Combina scatter plot com histogramas marginais para duas variáveis.

# %%
sns.jointplot(x = df['Faturamento'], y = df['Avaliacao'])

# %% [markdown]
# **9. Heatmap**
#
# --Mostra correlações ou intensidades em uma matriz.

# %%
sns.heatmap(df.corr(), annot=True)

#o df corr so funciona quando todo o dataframe é somente numeros
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1960736202.py in <cell line: 0>()
# ----> 1 sns.heatmap(df.corr(), annot=True)
#       2
#       3 #o df corr so funciona quando todo o dataframe é somente numeros
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   11047         cols = data.columns
#   11048         idx = cols.copy()
# > 11049         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11050
#   11051         if method == "pearson":
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1991         if dtype is not None:
#    1992             dtype = np.dtype(dtype)
# -> 1993         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994         if result.dtype is not dtype:
# ...

# %% [markdown]
# **10. Pairplot**
#
# --Cria múltiplos scatter plots para todas as combinações de variáveis numéricas.

# %%
sns.pairplot(df)
